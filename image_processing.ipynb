# %%
import numpy as np
import matplotlib.pylab as plt
from PIL import Image

# %%
im = np.array(Image.open('F:/images.jpg'))
print (im.shape, im.dtype)

im1 = np.array(Image.open('F:/images.jpg').convert('L'),'f')
print (im.shape, im.dtype)
# Out:
# (194, 259, 3) uint8
# (194, 259, 3) uint8

# %%
plt.imshow(im)

# %%
plt.imshow(im1)

# %%
from scipy.ndimage import filters
im3 = filters.gaussian_filter(im,3)

# %%
plt.imshow(im3)

# %%
from skimage import feature
edges1 = feature.canny(im1)
# edges2 = feature.canny(im1, sigma=3)

# %%
plt.imshow(edges1)

# %%
def simple_threshold(im, threshold=128):
    return ((im > threshold) * 255).astype("uint8")

thresholds = [100,120,128,138,150]

fig, axs = plt.subplots(nrows=1, ncols=len(thresholds), figsize=(20,5));

                        
for t, ax in zip(thresholds, axs):
    ax.imshow(simple_threshold(im1, t), cmap='Greys');
    ax.set_title("Threshold: {}".format(t), fontsize=20);
    ax.set_axis_off();
